# %% [markdown]
# 1. Generate edges and nodes from raw data

# %%
import pandas as pd

# %%
# raw data source
#path = 'data-seed/finance_20/'
path = 'data-random/'

# correspondent target
outpath = 'finance_20/random-test/test-network-features/'

# %%
followers = pd.read_csv(path+'follower_1.csv')
userdata = pd.read_csv(path+'user_data_1.csv')
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nometadata = followers[['id_follower']].drop_duplicates()

# %%
nometadata.shape
# Out:
# (3771006, 1)

# %%
nometadata.columns = ['id_user']

# %%
nodes = pd.concat([userdata, nometadata])
nodes.head(30)
# Out:
#              created_at  followers  following    id_user lang  \
# 0   2006-03-21 23:40:20    10332.0     1506.0         31   en
# 1   2009-05-23 17:20:24        3.0       13.0   42061773   en
# 2   2006-11-14 11:30:44      135.0      426.0      12365   en
# 3   2006-04-08 05:00:30     8773.0      288.0         94   en
# 4   2009-01-31 11:57:58        0.0        0.0   19812908   en
# 5   2006-04-01 02:05:22     2935.0      406.0         56   en
# 6   2007-03-02 15:39:35    10191.0    11486.0     806323   en
# 7   2006-05-24 15:51:44   127143.0     3408.0        295   en
# 8   2009-09-27 02:49:02       47.0       81.0   77641678   en
# 9   2006-08-21 17:44:39     1944.0      184.0       4563   en
# 10  2009-02-08 19:39:00      155.0      400.0   20387042   en
# 11  2007-09-04 18:51:39        2.0        1.0    8652612   en
# 12  2009-03-28 17:50:16        1.0        1.0   27273392   en
# 13  2006-11-13 17:39:34      266.0      497.0      12269   en
# 14  2006-03-21 21:04:12    14591.0     2442.0         22   en
# 15  2011-12-16 02:12:59       13.0        6.0  437985919   es
# 16  2006-07-23 21:11:45      397.0      755.0       2910   en
# 17  2006-12-09 01:53:45      509.0      867.0      52623   en
# 18  2010-09-21 12:54:00        0.0        0.0  193280501   en
# 19  2009-09-23 16:33:24       15.0       31.0   76686927   en
# 20  2009-12-12 22:46:10        6.0        1.0   96434321   en
# 21  2006-11-21 20:40:30      392.0      814.0      13639   en
# 22  2006-03-21 20:51:43  2804712.0     1009.0         13   en
# 23  2006-04-01 03:31:30     4255.0      685.0         58   en
# 24  2006-11-29 22:04:46      113.0      150.0      31293   it
# 25  2009-10-05 08:49:51        0.0       20.0   79969037   en
# 26  2009-05-02 16:39:17      303.0      496.0   37230631   en
# 27  2006-10-20 06:00:08     2276.0      983.0       9651   en
# 28  2006-09-05 00:50:29      243.0       19.0       5298   en
# 29  2006-07-16 19:05:36      374.0      291.0       1512   en
#
#                                              link_img             location  \
# 0   http://pbs.twimg.com/profile_images/8474930843...        San Francisco
# 1   http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 2   http://pbs.twimg.com/profile_images/1016647162...      London, England
# 3   http://pbs.twimg.com/profile_images/447830961/...           Denver, CO
# 4   http://abs.twimg.com/sticky/default_profile_im...          Not at work
# 5   http://pbs.twimg.com/profile_images/7207672576...        San Francisco
# 6   http://pbs.twimg.com/profile_images/9565597834...      Gainesville, FL
# 7   http://pbs.twimg.com/profile_images/3189077851...               Philly
# 8   http://pbs.twimg.com/profile_images/4414195732...              jakarta
# 9   http://pbs.twimg.com/profile_images/8457981050...                  NaN
# 10  http://pbs.twimg.com/profile_images/76539584/P...      Napa Valley, CA
# 11  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 12  http://pbs.twimg.com/profile_images/113040351/...                  NaN
# 13  http://pbs.twimg.com/profile_images/5429002162...  Fremont, California
# 14  http://pbs.twimg.com/profile_images/768793791/...            PDX & MVD
# 15  http://pbs.twimg.com/profile_images/1697524313...                  NaN
# 16  http://pbs.twimg.com/profile_images/820465487/...               canada
# 17  http://pbs.twimg.com/profile_images/6982980731...      berlin, germany
# 18  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 19  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 20  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 21  http://pbs.twimg.com/profile_images/5044557469...         Dayton, Ohio
# 22  http://pbs.twimg.com/profile_images/1000572120...    San Francisco, CA
# 23  http://pbs.twimg.com/profile_images/9780180445...     St louis city ⚜️
# 24  http://pbs.twimg.com/profile_images/5839653488...                  NaN
# 25  http://pbs.twimg.com/profile_images/453784846/...                  NaN
# 26  http://pbs.twimg.com/profile_images/6796784507...                  NaN
# 27  http://pbs.twimg.com/profile_images/67169723/c...        Vancouver, BC
# 28  http://pbs.twimg.com/profile_images/6113060053...         Kuala Lumpur
# 29  http://pbs.twimg.com/profile_images/5250643508...    San Francisco, CA
#
#        screen_name
# 0      rayreadyray
# 1       tonykostas
# 2        PederDray
# 3           alissa
# 4            TriFx
# 5             kati
# 6       vanhoosear
# 7            joshk
# 8       raniranuch
# 9         eeismann
# 10      JBartMoore
# 11        partonrl
# 12      GuzziShoes
# 13        mkgobaco
# 14          rabble
# 15  barservice24_7
# 16       jaspre150
# 17     joe_sixpack
# 18          mole00
# 19         Nwaugba
# 20        zetikala
# 21       cbethel10
# 22             biz
# 23        Darkside
# 24        riccard0
# 25        JONARD12
# 26    hannahmdavis
# 27       cbrumelle
# 28    praveenrajan
# 29     ryanpollock

# %%
nodes['followers'] = nodes.apply(lambda x: x['followers'] if not pd.isnull(x['followers']) else 1, axis=1)
nodes['following'] = nodes.apply(lambda x: x['following'] if not pd.isnull(x['following']) else 1, axis=1)

# %%
nodes.head(30)
# Out:
#              created_at  followers  following    id_user lang  \
# 0   2006-03-21 23:40:20    10332.0     1506.0         31   en
# 1   2009-05-23 17:20:24        3.0       13.0   42061773   en
# 2   2006-11-14 11:30:44      135.0      426.0      12365   en
# 3   2006-04-08 05:00:30     8773.0      288.0         94   en
# 4   2009-01-31 11:57:58        0.0        0.0   19812908   en
# 5   2006-04-01 02:05:22     2935.0      406.0         56   en
# 6   2007-03-02 15:39:35    10191.0    11486.0     806323   en
# 7   2006-05-24 15:51:44   127143.0     3408.0        295   en
# 8   2009-09-27 02:49:02       47.0       81.0   77641678   en
# 9   2006-08-21 17:44:39     1944.0      184.0       4563   en
# 10  2009-02-08 19:39:00      155.0      400.0   20387042   en
# 11  2007-09-04 18:51:39        2.0        1.0    8652612   en
# 12  2009-03-28 17:50:16        1.0        1.0   27273392   en
# 13  2006-11-13 17:39:34      266.0      497.0      12269   en
# 14  2006-03-21 21:04:12    14591.0     2442.0         22   en
# 15  2011-12-16 02:12:59       13.0        6.0  437985919   es
# 16  2006-07-23 21:11:45      397.0      755.0       2910   en
# 17  2006-12-09 01:53:45      509.0      867.0      52623   en
# 18  2010-09-21 12:54:00        0.0        0.0  193280501   en
# 19  2009-09-23 16:33:24       15.0       31.0   76686927   en
# 20  2009-12-12 22:46:10        6.0        1.0   96434321   en
# 21  2006-11-21 20:40:30      392.0      814.0      13639   en
# 22  2006-03-21 20:51:43  2804712.0     1009.0         13   en
# 23  2006-04-01 03:31:30     4255.0      685.0         58   en
# 24  2006-11-29 22:04:46      113.0      150.0      31293   it
# 25  2009-10-05 08:49:51        0.0       20.0   79969037   en
# 26  2009-05-02 16:39:17      303.0      496.0   37230631   en
# 27  2006-10-20 06:00:08     2276.0      983.0       9651   en
# 28  2006-09-05 00:50:29      243.0       19.0       5298   en
# 29  2006-07-16 19:05:36      374.0      291.0       1512   en
#
#                                              link_img             location  \
# 0   http://pbs.twimg.com/profile_images/8474930843...        San Francisco
# 1   http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 2   http://pbs.twimg.com/profile_images/1016647162...      London, England
# 3   http://pbs.twimg.com/profile_images/447830961/...           Denver, CO
# 4   http://abs.twimg.com/sticky/default_profile_im...          Not at work
# 5   http://pbs.twimg.com/profile_images/7207672576...        San Francisco
# 6   http://pbs.twimg.com/profile_images/9565597834...      Gainesville, FL
# 7   http://pbs.twimg.com/profile_images/3189077851...               Philly
# 8   http://pbs.twimg.com/profile_images/4414195732...              jakarta
# 9   http://pbs.twimg.com/profile_images/8457981050...                  NaN
# 10  http://pbs.twimg.com/profile_images/76539584/P...      Napa Valley, CA
# 11  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 12  http://pbs.twimg.com/profile_images/113040351/...                  NaN
# 13  http://pbs.twimg.com/profile_images/5429002162...  Fremont, California
# 14  http://pbs.twimg.com/profile_images/768793791/...            PDX & MVD
# 15  http://pbs.twimg.com/profile_images/1697524313...                  NaN
# 16  http://pbs.twimg.com/profile_images/820465487/...               canada
# 17  http://pbs.twimg.com/profile_images/6982980731...      berlin, germany
# 18  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 19  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 20  http://abs.twimg.com/sticky/default_profile_im...                  NaN
# 21  http://pbs.twimg.com/profile_images/5044557469...         Dayton, Ohio
# 22  http://pbs.twimg.com/profile_images/1000572120...    San Francisco, CA
# 23  http://pbs.twimg.com/profile_images/9780180445...     St louis city ⚜️
# 24  http://pbs.twimg.com/profile_images/5839653488...                  NaN
# 25  http://pbs.twimg.com/profile_images/453784846/...                  NaN
# 26  http://pbs.twimg.com/profile_images/6796784507...                  NaN
# 27  http://pbs.twimg.com/profile_images/67169723/c...        Vancouver, BC
# 28  http://pbs.twimg.com/profile_images/6113060053...         Kuala Lumpur
# 29  http://pbs.twimg.com/profile_images/5250643508...    San Francisco, CA
#
#        screen_name
# 0      rayreadyray
# 1       tonykostas
# 2        PederDray
# 3           alissa
# 4            TriFx
# 5             kati
# 6       vanhoosear
# 7            joshk
# 8       raniranuch
# 9         eeismann
# 10      JBartMoore
# 11        partonrl
# 12      GuzziShoes
# 13        mkgobaco
# 14          rabble
# 15  barservice24_7
# 16       jaspre150
# 17     joe_sixpack
# 18          mole00
# 19         Nwaugba
# 20        zetikala
# 21       cbethel10
# 22             biz
# 23        Darkside
# 24        riccard0
# 25        JONARD12
# 26    hannahmdavis
# 27       cbrumelle
# 28    praveenrajan
# 29     ryanpollock

# %%
# for visualization, use id field instead of id_user
nodes.columns = [u'created_at', u'followers', u'following', u'id', u'lang',
       u'link_img', u'location', u'screen_name']

# %%
nodes.drop_duplicates(subset='id', inplace=True)

# %%
nodes[['id','followers','following']].to_csv(outpath+'followers_network_nodes_1.csv', index=None)

# %%
# needed for Gephi viz
followers.columns = ['source', 'target']

# %%
followers.to_csv(outpath+'followers_network_edges.csv_1', index=None)

# %% [markdown]
# 2. Generate network using SNAP

# %%
import snap

# %%
edgefile = outpath+'followers_network_edges.csv'
nodefile = outpath+'followers_network_nodes.csv'

# %%
def generateTables(targetpath, netfile, net):
    #split file into node and edge file
    net_file = open(targetpath+netfile+'.csv', 'r') 
    nodes_file = open(targetpath+netfile+'_nodes.csv', 'w')
    nodes_file.write('id\tfollowers\tfollowing\tid_user\n')
    edges_file = open(targetpath+netfile+'_edges.csv', 'w')
    edges_file.write('source\ttarget\n')

    n_nodes = net.GetNodes()
    n_edges = net.GetEdges()

    line_num = 0 
    for line in net_file:
        if line_num>=4 and line_num < (n_nodes+4) : # 4 headers
            nodes_file.write(line)
        elif line_num >= (n_nodes+6) and line_num < (n_nodes+6+n_edges): #skip #END
            edges_file.write(line)
        line_num = line_num + 1

# %%
## NETWORK CONSTRUCTION ##
e_schema = snap.Schema()
e_schema.Add(snap.TStrTAttrPr("source", snap.atStr))
e_schema.Add(snap.TStrTAttrPr("target", snap.atStr)) 

n_schema = snap.Schema()
n_schema.Add(snap.TStrTAttrPr("id", snap.atStr))
n_schema.Add(snap.TStrTAttrPr("followers", snap.atFlt))
n_schema.Add(snap.TStrTAttrPr("following", snap.atFlt))

#define TTable objects of edges and nodes
context = snap.TTableContext()
edgetable = snap.TTable.LoadSS(e_schema, edgefile, context, ",", snap.TBool(True))
nodetable = snap.TTable.LoadSS(n_schema, nodefile, context, ",", snap.TBool(True))

#define (if any) attribute names using SNAP string vectors
edgeattrv = snap.TStrV()

nodeattrv = snap.TStrV()
nodeattrv.Add("following")
nodeattrv.Add("followers")
nodeattrv.Add("id")

#build SNAP network using the two TTable objects
net = snap.ToNetwork(snap.PNEANet, edgetable, "source", "target", edgeattrv, nodetable, "id", nodeattrv, snap.aaFirst)

# %%
print 'Nodes '+str(net.GetNodes())
print 'Edges '+str(net.GetEdges())
# Out:
# Nodes 3654338
# Edges 4342688

# %%
DegToCntV = snap.TIntPrV()
snap.GetInDegCnt(net, DegToCntV)

# %%
for item in DegToCntV:
    print "%d nodes with degree %d" % (item.GetVal2(), item.GetVal1())
# Out:
# 3654289 nodes with degree 0
# 1 nodes with degree 1
# 1 nodes with degree 2
# 1 nodes with degree 4
# 2 nodes with degree 6
# 2 nodes with degree 12
# 2 nodes with degree 18
# 1 nodes with degree 22
# 1 nodes with degree 26
# 1 nodes with degree 30
# 1 nodes with degree 42
# 1 nodes with degree 62
# 1 nodes with degree 94
# 1 nodes with degree 105
# 1 nodes with degree 140
# 1 nodes with degree 178
# 1 nodes with degree 226
# 1 nodes with degree 270
# 1 nodes with degree 310
# 1 nodes with degree 486
# 1 nodes with degree 532
# 1 nodes with degree 566
# 1 nodes with degree 606
# 1 nodes with degree 614
# 1 nodes with degree 748
# 1 nodes with degree 784
# 1 nodes with degree 1191
# 1 nodes with degree 1260
# 1 nodes with degree 1386
# 1 nodes with degree 1525
# 1 nodes with degree 3888
# 1 nodes with degree 4552
# 1 nodes with degree 9327
# 1 nodes with degree 12761
# 1 nodes with degree 13095
# 1 nodes with degree 17449
# 1 nodes with degree 20652
# 1 nodes with degree 20665
# 1 nodes with degree 23832
# 1 nodes with degree 23980
# 1 nodes with degree 31027
# 1 nodes with degree 36038
# 1 nodes with degree 45179
# 1 nodes with degree 48338
# 1 nodes with degree 255458
# 1 nodes with degree 709801
# 1 nodes with degree 3055364

# %%
snap.DelDegKNodes(net, 1, -1)

# %%
print 'Nodes '+str(net.GetNodes())
print 'Edges '+str(net.GetEdges())
# Out:
# Nodes 496037
# Edges 1184387

# %%
networkname = 'followers_core_network_1'
#save network for metadata and visualization
snap.SaveEdgeListNet(net, outpath+networkname+'.csv', 'Followers Core Network')
generateTables(outpath, networkname, net)

#save network for node2vec input
snap.SaveEdgeList(net, outpath+networkname+'.edgelist')
