# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import snap

# %matplotlib inline

# %%
# load matrix
matrix = pd.read_csv('finance_matrix.csv', index_col=['Unnamed: 0'])
matrix.head()
# Out:
#                bill_easterly  economisthulk  economistmeg  eu_eurostat  \
# bill_easterly       0.000000       0.992771      0.873616     0.918270
# economisthulk       0.992771       0.000000      0.974031     0.988059
# economistmeg        0.873616       0.974031      0.000000     0.757894
# eu_eurostat         0.918270       0.988059      0.757894     0.000000
# ezraklein           0.903705       0.991730      0.847303     0.994572
#
#                ezraklein  faulljonathan    fgoria  firoozye  justinwolfers  \
# bill_easterly   0.903705       0.936851  0.927467  0.858627       0.916398
# economisthulk   0.991730       0.981914  0.992053  0.994488       0.998243
# economistmeg    0.847303       0.616167  0.909355  0.841064       0.904317
# eu_eurostat     0.994572       0.505462  0.940154  0.911201       0.996032
# ezraklein       0.000000       0.991663  0.940733  0.698908       0.830198
#
#                kathylienfx     ...        michalp  freshfunk5      elly  \
# ...

# %%
# get distribution of distances
matrix.boxplot(figsize=(20, 8))

# %%
# load graph
# mention
g = snap.LoadEdgeListNet('random-test/test-network-features/m_network_1.csv', '\t')

# %%
# define minimum distance as default value for weight
for v in matrix.values:

# %%
# add weight attribute
# g.AddFloatAttr('weight')

E = g.GetEdges()
it = g.BegEI()
for i in range(E)
    
    src = it.GetSrcNId()
    src_user = g.GetStrAttrDatN(src, 'content')
    tgt = it.GetDstNId()
    tgt_user = g.GetStrAttrDatN(tgt, 'content')
    
    it.Next()
